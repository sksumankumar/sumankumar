# %%
fruit = ["Apple","Banana","greap","Apricot","Orange"]
filter_object = filter(lambda s:s[0] == "g",fruit)
print(list(filter_object))
# Out:
# ['greap']

# %%
from functools import reduce
list =[2,4,7,3]
print(reduce(lambda x,y:x+y,list))
print("With an initial value:",str(reduce(lambda 
x,y:x+y,list,10)))
# Out:
# 16
# With an initial value: 26

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot  as plt
cars_df=pd.read_csv("C:\\Users\\GPT BANTWAL\\Downloads\\Cars93.csv")
cars_df
# Out:
#     Unnamed: 0 Manufacturer    Model     Type  Min.Price  Price  Max.Price  \
# 0            1        Acura  Integra    Small       12.9   15.9       18.8
# 1            2        Acura   Legend  Midsize       29.2   33.9       38.7
# 2            3         Audi       90  Compact       25.9   29.1       32.3
# 3            4         Audi      100  Midsize       30.8   37.7       44.6
# 4            5          BMW     535i  Midsize       23.7   30.0       36.2
# ..         ...          ...      ...      ...        ...    ...        ...
# 88          89   Volkswagen  Eurovan      Van       16.6   19.7       22.7
# 89          90   Volkswagen   Passat  Compact       17.6   20.0       22.4
# 90          91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7
# 91          92        Volvo      240  Compact       21.8   22.7       23.5
# 92          93        Volvo      850  Midsize       24.8   26.7       28.5
#
# ...

# %%
coloumns=["Manufacturer","Model","Model","MPG.city","MPG.highway","Passengers","Length","Price"]
cars_df[coloumns].head()
# Out:
#   Manufacturer    Model    Model  MPG.city  MPG.highway  Passengers  Length  \
# 0        Acura  Integra  Integra        25           31           5     177
# 1        Acura   Legend   Legend        18           25           5     195
# 2         Audi       90       90        20           26           5     180
# 3         Audi      100      100        19           26           6     193
# 4          BMW     535i     535i        22           30           4     186
#
#    Price
# 0   15.9
# 1   33.9
# 2   29.1
# 3   37.7
# 4   30.0

# %%
cars_df["Price"].plot(kind="box",figsize=(3,3))
# Out:
# <Axes: >

# %%
fig,(ax1,ax2)=plt.subplots(1,2)
fig.set_figwidth(8)
fig.set_figwidth(8)
ax1.boxplot(cars_df["MPG.highway"])
ax2.boxplot(cars_df["MPG.city"])
ax1.set_title("MPG.highway")
ax2.set_xlabel("MPG.highway")
ax2.set_title("Passengers")
ax2.set_xlabel("Length")
fig.tight.layout()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 10
#       8 ax2.set_title("Passengers")
#       9 ax2.set_xlabel("Length")
# ---> 10 fig.tight.layout()
#
# AttributeError: 'Figure' object has no attribute 'tight'
